# %%
import iglu
import pandas as pd

# print(iglu.iglu.sd_roc)
data = pd.read_csv('../data/example_data_1_subject.csv', index_col=0)

print(iglu.mean_glu(data))
iglu.above_percent(data)

plot = iglu.mage(data, plot=True, show_excursions=False)
# Out:
#           id        mean
# 1  Subject 1  123.665523
# [1] "[Subject 1: 2015-06-06 16:55:00 to 2015-06-07 14:45:00]"
# [1] "[Subject 1: 2015-06-07 19:20:00 to 2015-06-10 11:45:00]"
# [1] "[Subject 1: 2015-06-10 17:25:00 to 2015-06-12 10:20:00]"
# [1] "[Subject 1: 2015-06-12 14:00:00 to 2015-06-12 14:10:00]"
# [1] "[Subject 1: 2015-06-12 21:05:00 to 2015-06-19 08:55:00]"

# %%
plot
# Out:
# R[write to console]: Error in print(..., self = self) : unused argument (useS4 = FALSE)
#
# R[write to console]: In addition:
# R[write to console]: Warning message:
#
# R[write to console]: In mage_atomic(e) :
# R[write to console]:
#
# R[write to console]:  [Subject 1: 2015-06-12 14:00:00 to 2015-06-12 14:10:00] The number of measurements (3) is too small for MAGE calculation. Returning NA for this segment.
#
# /Users/nathanielfernandes/miniconda3/envs/iglu-py/lib/python3.10/site-packages/rpy2/robjects/robject.py:123: UserWarning: Invalid call to "show()" in R: Error in print(..., self = self) : unused argument (useS4 = FALSE)
#
#   warnings.warn(f'Invalid call to "show()" in R: {rre}')
# ...

# %%
iglu.active_percent(data)
# Out:
#           id  active_percent  ndays                start_date  \
# 1  Subject 1       79.841139   12.7 2015-06-06 16:50:27-05:00
#
#                    end_date
# 1 2015-06-19 08:59:36-05:00

# %%
iglu.adrr(data)
# Out:
#           id       ADRR
# 1  Subject 1  15.101109

# %%
iglu.agp(data)
# Out:
# R[write to console]: Error in print(..., self = self) : unused argument (useS4 = FALSE)
#
# /Users/nathanielfernandes/miniconda3/envs/iglu-py/lib/python3.10/site-packages/rpy2/robjects/robject.py:123: UserWarning: Invalid call to "show()" in R: Error in print(..., self = self) : unused argument (useS4 = FALSE)
#
#   warnings.warn(f'Invalid call to "show()" in R: {rre}')
# R[write to console]: Error in print(..., self = self) : unused argument (useS4 = FALSE)
#
# R[write to console]: Error in print(..., self = self) : unused argument (useS4 = FALSE)
#
# R[write to console]: Error in print(..., self = self) : unused argument (useS4 = FALSE)
#
# R[write to console]: Error in print(..., self = self) : unused argument (useS4 = FALSE)
#
# /Users/nathanielfernandes/miniconda3/envs/iglu-py/lib/python3.10/site-packages/rpy2/robjects/robject.py:123: UserWarning: Invalid call to "show()" in R: Error in print(..., self = self) : unused argument (useS4 = FALSE)
#
# ...

# %%
print(iglu.auc(data))
# Out:
#           id  hourly_auc
# 1  Subject 1  123.244022

# %%
iglu.agp_metrics(data)
# Out:
#           id                start_date                  end_date  ndays  \
# 1  Subject 1 2015-06-06 16:50:27-05:00 2015-06-19 08:59:36-05:00   12.7
#
#    active_percent        mean       GMI         CV  below_54  below_70  \
# 1       79.841139  123.665523  6.268079  26.901658       0.0  0.137221
#
#    in_range_70_180  above_180  above_250
# 1        91.663808   8.198971   0.377358

# %%
iglu.mad_glu(data)
# Out:
#           id      MAD
# 1  Subject 1  25.2042

# %%
iglu.j_index(data)
# Out:
#           id    J_index
# 1  Subject 1  24.628155

# %%
iglu.cv_glu(data)
# Out:
#           id         CV
# 1  Subject 1  26.901658

# %%
iglu.mean_glu(data)
# Out:
#           id        mean
# 1  Subject 1  123.665523

# %%
iglu.median_glu(data)
# Out:
#           id  median
# 1  Subject 1     112

# %%
iglu.mag(data)
# Out:
#           id        MAG
# 1  Subject 1  17.010839

# %%
iglu.mage(data)
# Out:
#           id       MAGE
# 1  Subject 1  87.166479
